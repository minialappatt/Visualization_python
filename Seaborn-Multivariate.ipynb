# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/AIP-BITS/DataViz/main/DataViz/Seaborn/spotify.csv")

# %%
data.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      366 non-null    object
#  1   Shape of You              366 non-null    int64
#  2   Despacito                 359 non-null    float64
#  3   Something Just Like This  319 non-null    float64
#  4   HUMBLE.                   282 non-null    float64
#  5   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
data = pd.read_csv("https://raw.githubusercontent.com/AIP-BITS/DataViz/main/DataViz/Seaborn/spotify.csv",parse_dates=True,index_col="Date")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2017-01-06 to 2018-01-09
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Shape of You              366 non-null    int64
#  1   Despacito                 359 non-null    float64
#  2   Something Just Like This  319 non-null    float64
#  3   HUMBLE.                   282 non-null    float64
#  4   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 17.2 KB

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=data)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=data['Shape of You'],label='shapeofyou')
sns.lineplot(data=data['Despacito'],label='despacito')
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
data_new = pd.read_csv('https://raw.githubusercontent.com/AIP-BITS/DataViz/main/DataViz/Seaborn/museum_visitors.csv')

sns.lineplot(data_new)
# Out:
# <Axes: >

# %%
data_new = pd.read_csv('https://raw.githubusercontent.com/AIP-BITS/DataViz/main/DataViz/Seaborn/museum_visitors.csv')
data_new.Date = data_new.Date.astype('datetime64')

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  59 non-null     datetime64[ns]
#  1   Avila Adobe                           59 non-null     int64
#  2   Firehouse Museum                      59 non-null     int64
#  3   Chinese American Museum               59 non-null     int64
#  4   America Tropical Interpretive Center  59 non-null     int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 2.4 KB

# %%
sns.lineplot(data=data_new,x=data_new.Date,y=data_new["Avila Adobe"])
sns.lineplot(data=data_new,x=data_new.Date,y=data_new["Firehouse Museum"])
sns.lineplot(data=data_new,x=data_new.Date,y=data_new["Chinese American Museum"])
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/AIP-BITS/DataViz/main/DataViz/Seaborn/flight_delays.csv")
df.head()
# Out:
#    Month        AA        AS         B6        DL         EV         F9  \
# 0      1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1      2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 2      3  6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 3      4  4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 4      5  5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#          HA         MQ         NK         OO        UA        US        VX  \
# 0  3.512640  18.164974  11.398054  10.889894  6.352729  3.107457  1.420702
# 1  6.029967  21.301627  16.474466   9.588895  7.260662  7.114455  7.784410
# 2  3.468383  11.018418  10.039118   3.181693  4.892212  3.330787  5.348207
# 3  0.011022   5.131228   8.766224   3.223796  4.376092  2.660290  0.995507
# 4  0.826426   5.466790  22.397347   4.141162  6.827695  0.681605  7.102021
#
#          WN
# 0  3.389466
# 1  3.501363
# 2  3.263341
# 3  2.996399
# 4  5.680777

# %%
df.NK.describe()
# Out:
# count    12.000000
# mean     14.549663
# std       8.319500
# min       6.810736
# 25%       8.574693
# 50%      12.065589
# 75%      17.485604
# max      35.561501
# Name: NK, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Create a bar plot
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='Month', y='NK', data=df, color='skyblue')
op
# Draw a threshold line at 15
threshold = 15
plt.axhline(y=threshold, color='red', linestyle='--')

# Change the color of bars above the threshold
for p in barplot.patches:
    if p.get_height() > threshold:
        p.set_color('orange')

plt.title('Total delay')
plt.xlabel('Month')
plt.ylabel('Delay')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Create a bar plot
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x='Month', y='NK', data=df, color='skyblue')

# Draw a threshold line at 15
threshold = 15
plt.axhline(y=threshold, color='red', linestyle='--')
winter = [11,12,1,2]
winter_thresh = 18
clrs = ['grey' if x<18 and y in winter else 'red' for x in df.NK for y in df.Month]
# clrs = [(x,y) for x in df.NK for y in df.Month]
# clrs = ['grey' if (x<18 and df.Month.isin(winter)) else 'red' for x in df.NK]
sns.barplot(x=df.Month,y=df.NK,palette=clrs)
plt.title('Total delay')
plt.xlabel('Month')
plt.ylabel('Delay')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-53-a067cc4ac55a>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df.Month,y=df.NK,palette=clrs)
# <ipython-input-53-a067cc4ac55a>:18: UserWarning: The palette list has more values (144) than needed (12), which may not be intended.
#   sns.barplot(x=df.Month,y=df.NK,palette=clrs)

# %%
iris = sns.load_dataset('iris')
sns.jointplot(data=iris,x='sepal_length',y='petal_length',hue='species')

# %%
iris = sns.load_dataset('iris')
sns.pairplot(data=iris,hue='species')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='time',size='size')
