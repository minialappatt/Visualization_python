# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.xlabel('z-values')
z=np.linspace(1,10,20)
plt.plot(z,label='test plot')
plt.legend()
plt.show()

# %%
explode = (******)
x=['A','B','C','D']
y=np.array([30,40,10,20])
plt.pie(y,
       labels=x,
       autopct='%.2f',
       explode=explode)
plt.axis('equal')
# Out:
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_33196\4169845151.py", line 1
#     explode = (******)
#                ^
# SyntaxError: invalid syntax

# %%
explode = (0, 0.1, 0, 0)  # Explode the second slice (B) outwards by 10%

x = ['A', 'B', 'C', 'D']
y = np.array([30, 40, 10, 20])

plt.pie(y, labels=x, autopct='%.2f', explode=explode)
plt.axis('equal')
plt.show()

# %%
fig,ax=plt.subplots()
ax.set_aspect(aspect='equal')
ax.add_patch(
patches.Rectangle(
(0.1,0.1),0.5,0.5,
fill=false
)
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33196\973963313.py in <module>
#       2 ax.set_aspect(aspect='equal')
#       3 ax.add_patch(
# ----> 4 patches.Rectangle(
#       5 (0.1,0.1),0.5,0.5,
#       6 fill=false
#
# NameError: name 'patches' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

fig, ax = plt.subplots()
ax.set_aspect(aspect='equal')
ax.add_patch(
    patches.Rectangle(
        (0.1, 0.1),  # (x,y)
        0.5,          # width
        0.5,          # height
        fill=False    # fill parameter should be False
    )
)
plt.show()

# %%
plt.legend()
x-np.linspace(1,10,20)
plt.show()
plt.xlabel('x-Label')
plt.plot(x,label='example plot')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33196\4149675116.py in <module>
#       1 plt.legend()
# ----> 2 x-np.linspace(1,10,20)
#       3 plt.show()
#       4 plt.xlabel('x-Label')
#       5 plt.plot(x,label='example plot')
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U1'), dtype('float64')) -> None

# %%
x = np.linspace(1, 10, 20)  # Correcting assignment of x

plt.plot(x, label='example plot')  # Plotting with label
plt.xlabel('x-Label')  # Setting x-axis label
plt.legend()  # Showing legend after plotting
plt.show()

# %%
fig=plt.figure()
*******
ax2=fig.add_axes([0.5,0.5,0.4,0.4])
# Out:
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_33196\1059440821.py", line 2
#     *******
#     ^
# SyntaxError: invalid syntax

# %%
plt.legend(loc='upper')
plt.legend('upper')
plt.legend('center')
plt.legend(loc='upper center')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33196\986445761.py in <module>
# ----> 1 plt.legend(loc='upper')
#       2 plt.legend('upper')
#       3 plt.legend('center')
#       4 plt.legend(loc='upper center')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    2665 @_copy_docstring_and_deprecators(Axes.legend)
#    2666 def legend(*args, **kwargs):
# -> 2667     return gca().legend(*args, **kwargs)
#    2668
#    2669
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     303         if len(extra_args):
#     304             raise TypeError('legend only accepts two non-keyword arguments')
# ...

# %%
plt.legend(loc='upper center')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
